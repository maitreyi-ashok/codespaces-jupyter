# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np 

import seaborn as sns 
df_train=pd.read_csv("/kaggle/input/musicdata/train.csv/train.csv")
df_train.head(10)
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 5  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 6  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 7  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 8  uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 9  uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
# ...

# %%
# Sampling Only Half the Data
df_train = df_train.sample(frac=0.5)

# %%
df_train.head(5)
# Out:
#                                                  msno  \
# 6452103  5DQDcoAktYDfnlFU2k/k4pfcwbZIXRKQ/1+pgAhZqvA=
# 663805   nCV0uXlTHdN56QKfSCIQ3df2ZcSEQLUgUS8Ww70d4FE=
# 5185014  ruHELMXIB2cbqASibpyz1OlyWHrdp1pvuo/aMgfu/nE=
# 1862755  wAvvnIEWYZ/yMluuaX55pLwryVB1tcqoYi4R4NtGuWc=
# 3578793  xaSPzpHG21RbnMuRecbNLlMQDEcETfOJUe2CBQ/eYoQ=
#
#                                               song_id source_system_tab  \
# 6452103  hX0G6QpFYwNuS7JfqtvDJpka5M+JgcS4T4NS/Q/BukM=          discover
# 663805   IKMFuL0f5Y8c63Hg9BXkeNJjE0z8yf3gMt/tOxF4QNE=        my library
# 5185014  wOC3k05ydf9/8wlRWU7eu7SszQTO4FoIchEoWCj4EqY=             radio
# 1862755  yn6Kt6+romPpZ1i6+hqI3WJ42G5SdsX3a+l59IaMcp4=          discover
# 3578793  Oo+q5PWuq4hh774jIAnHYWPzfkoIZTgRE4pDsfPQnCM=            search
#
#           source_screen_name          source_type  target
# 6452103       Discover Genre      online-playlist       0
# 663805   Local playlist more        local-library       1
# ...

# %%
df_songs=pd.read_csv("/kaggle/input/musicdata/songs.csv/songs.csv")
df_songs.head(5)
# Out:
#                                         song_id  song_length genre_ids  \
# 0  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640       465
# 1  o0kFgae9QtnYgRkVPqLJwa05zIhRlUjfF7O1tDw0ZDU=       197328       444
# 2  DwVvVurfpuz+XPuFvucclVQEyPqcpUkHR0ne1RQzPs0=       231781       465
# 3  dKMBWoZyScdxSkihKG+Vf47nc18N9q4m58+b4e7dSSE=       273554       465
# 4  W3bqWd3T+VeHFzHAUfARgW9AvVRaF4N5Yzm4Mr6Eo/o=       140329       726
#
#         artist_name                            composer     lyricist  language
# 0  張信哲 (Jeff Chang)                                  董貞          何啟弘       3.0
# 1         BLACKPINK  TEDDY|  FUTURE BOUNCE|  Bekuh BOOM        TEDDY      31.0
# 2      SUPER JUNIOR                                 NaN          NaN      31.0
# 3             S.H.E                                 湯小康          徐世珍       3.0
# 4              貴族精選                         Traditional  Traditional      52.0

# %%
df_songs_info=pd.read_csv("/kaggle/input/musicdata/song_extra_info.csv/song_extra_info.csv")
df_songs_info.head(5)
# Out:
#                                         song_id             name          isrc
# 0  LP7pLJoJFBvyuUwvu+oLzjT+bI+UeBPURCecJsX1jjs=               我們  TWUM71200043
# 1  ClazTFnk6r0Bnuie44bocdNMM3rdlrq0bCGAsGUWcHE=  Let Me Love You  QMZSY1600015
# 2  u2ja/bZE3zhCGxvbbOB3zOoUjx27u40cf5g09UXMoKQ=              原諒我  TWA530887303
# 3  92Fqsy0+p6+RHe2EoLKjHahORHR1Kq1TBJoClW9v+Ts=          Classic  USSM11301446
# 4  0QFmz/+rJy1Q56C1DuYqT9hKKqi5TUqx0sN0IwvoHrw=             愛投羅網  TWA471306001

# %%
df_song_detail = pd.merge(pd.merge(df_songs, df_songs_info, on='song_id'), df_train, on='song_id')
df_song_detail.head(5)
# Out:
#                                         song_id  song_length genre_ids  \
# 0  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640       465
# 1  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640       465
# 2  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640       465
# 3  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640       465
# 4  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640       465
#
#         artist_name composer lyricist  language name          isrc  \
# 0  張信哲 (Jeff Chang)       董貞      何啟弘       3.0   焚情  TWB531410010
# 1  張信哲 (Jeff Chang)       董貞      何啟弘       3.0   焚情  TWB531410010
# 2  張信哲 (Jeff Chang)       董貞      何啟弘       3.0   焚情  TWB531410010
# 3  張信哲 (Jeff Chang)       董貞      何啟弘       3.0   焚情  TWB531410010
# 4  張信哲 (Jeff Chang)       董貞      何啟弘       3.0   焚情  TWB531410010
#
#                                            msno source_system_tab  \
# ...

# %%
df_mem=pd.read_csv("/kaggle/input/musicdata/members.csv/members.csv")
df_mem.head(5)
# Out:
#                                            msno  city  bd gender  \
# 0  XQxgAYj3klVKjR3oxPPXYYFp4soD4TuBghkhMTD4oTw=     1   0    NaN
# 1  UizsfmJb9mV54qE9hCYyU07Va97c0lCRLEQX3ae+ztM=     1   0    NaN
# 2  D8nEhsIOBSoE6VthTaqDX8U6lqjJ7dLdr72mOyLya2A=     1   0    NaN
# 3  mCuD+tZ1hERA/o5GPqk38e041J8ZsBaLcu7nGoIIvhI=     1   0    NaN
# 4  q4HRBfVSssAFS9iRfxWrohxuk9kCYMKjHOEagUMV6rQ=     1   0    NaN
#
#    registered_via  registration_init_time  expiration_date
# 0               7                20110820         20170920
# 1               7                20150628         20170622
# 2               4                20160411         20170712
# 3               9                20150906         20150907
# 4               4                20170126         20170613

# %%
df=pd.merge(df_song_detail,df_mem,on='msno')

# %%
df.head(5)
# Out:
#                                         song_id  song_length genre_ids  \
# 0  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640       465
# 1  uWREia5CNSoapbU9+BpqQxlSfntw1J/01HQGpVxFiM4=       283898       NaN
# 2  f8/yxXLT8/hENDkcudzHhytnOwyUKJ+/JCY7Y+L/Gsw=       237600       458
# 3  eW1d3l1sSncU4sGM69MJtIG79wnXbdy8FZKpFVElS0g=       205264       465
# 4  d2k4F/IYpmudgfCxsRAXVHBdYHPfcWmhCYmjdXxigLE=       225567  465|1259
#
#                         artist_name                                 composer  \
# 0                  張信哲 (Jeff Chang)                                       董貞
# 1                  曾沛慈 (Pets Tseng)                                      鴉片丹
# 2  八三夭 (The Last Day of Summer 831)                                   八三夭 阿璞
# 3                         Lady Gaga  Lady Gaga| Mark Ronson| Hillary Lindsey
# 4                               玖壹壹                                      陳皓宇
#
#   lyricist  language                       name          isrc  \
# ...

# %%
df.shape
# Out:
# (3687899, 20)

# %%
missing_values = df.isna()

# Count the missing values in each column
missing_counts = missing_values.sum()
missing_counts
# Out:
# song_id                         0
# song_length                     0
# genre_ids                   58905
# artist_name                     0
# composer                   838617
# lyricist                  1589903
# language                       19
# name                            0
# isrc                       288446
# msno                            0
# source_system_tab           12430
# source_screen_name         207271
# source_type                 10741
# target                          0
# city                            0
# bd                              0
# gender                    1480106
# registered_via                  0
# registration_init_time          0
# expiration_date                 0
# dtype: int64

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (1099686, 20)

# %%
df.isna()
# Out:
#          song_id  song_length  genre_ids  artist_name  composer  lyricist  \
# 0          False        False      False        False     False     False
# 2          False        False      False        False     False     False
# 5          False        False      False        False     False     False
# 6          False        False      False        False     False     False
# 8          False        False      False        False     False     False
# ...          ...          ...        ...          ...       ...       ...
# 3687835    False        False      False        False     False     False
# 3687836    False        False      False        False     False     False
# 3687860    False        False      False        False     False     False
# 3687881    False        False      False        False     False     False
# 3687887    False        False      False        False     False     False
#
#          language   name   isrc   msno  source_system_tab  source_screen_name  \
# ...

# %%
df.isna().sum()
# Out:
# song_id                   0
# song_length               0
# genre_ids                 0
# artist_name               0
# composer                  0
# lyricist                  0
# language                  0
# name                      0
# isrc                      0
# msno                      0
# source_system_tab         0
# source_screen_name        0
# source_type               0
# target                    0
# city                      0
# bd                        0
# gender                    0
# registered_via            0
# registration_init_time    0
# expiration_date           0
# dtype: int64

# %%
df.head(5)
# Out:
#                                         song_id  song_length genre_ids  \
# 0  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640       465
# 2  f8/yxXLT8/hENDkcudzHhytnOwyUKJ+/JCY7Y+L/Gsw=       237600       458
# 5  reXuGcEWDDCnL0K3Th//3DFG4S1ACSpJMzA+CFipo1g=       219324       458
# 6  AeFYUj/BA1epsa5mS3uQxbbS04PKiUr84gSVH430N24=       234631       458
# 8  F3L07h2BkUox3Uub/4K9LZ8Hg1JTlB2iEOEE9WpZ57A=       219350       458
#
#                         artist_name   composer         lyricist  language  \
# 0                  張信哲 (Jeff Chang)         董貞              何啟弘       3.0
# 2  八三夭 (The Last Day of Summer 831)     八三夭 阿璞           八三夭 阿璞       3.0
# 5                 周湯豪 (NICKTHEREAL)        周湯豪          周湯豪\崔惟楷       3.0
# 6                          Eric 周興哲  Eric Chou        Eric Chou       3.0
# 8                          Eric 周興哲  Eric Chou  Night Chun| Liv       3.0
#
#                         name          isrc  \
# 0                         焚情  TWB531410010
# ...

# %%
df.corr()
# Out:
#                         song_id  song_length  genre_ids  artist_name  \
# song_id                1.000000    -0.059633  -0.023206    -0.027561
# song_length           -0.059633     1.000000   0.113147     0.184922
# genre_ids             -0.023206     0.113147   1.000000     0.180089
# artist_name           -0.027561     0.184922   0.180089     1.000000
# composer              -0.066066     0.172452   0.195975     0.426383
# lyricist              -0.055313     0.203630   0.211820     0.430583
# language               0.035133    -0.327485  -0.331756    -0.552784
# name                  -0.046576     0.269226   0.219210     0.428531
# isrc                  -0.017697     0.066843  -0.004953     0.141029
# msno                   0.000236     0.002771   0.004128     0.004679
# source_system_tab     -0.003906     0.058474   0.058701     0.078376
# source_screen_name    -0.001681     0.018610   0.014327     0.017610
# source_type            0.002158    -0.013190  -0.041427    -0.019439
# ...

# %%
fig, ax = plt.subplots(figsize=(25, 20)) 
sns.heatmap(df.corr(), annot=True,ax=ax)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1099686 entries, 0 to 3687887
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   song_id                 1099686 non-null  object
#  1   song_length             1099686 non-null  int64
#  2   genre_ids               1099686 non-null  object
#  3   artist_name             1099686 non-null  object
#  4   composer                1099686 non-null  object
#  5   lyricist                1099686 non-null  object
#  6   language                1099686 non-null  float64
#  7   name                    1099686 non-null  object
#  8   isrc                    1099686 non-null  object
#  9   msno                    1099686 non-null  object
#  10  source_system_tab       1099686 non-null  object
#  11  source_screen_name      1099686 non-null  object
#  12  source_type             1099686 non-null  object
# ...

# %%
df.describe()
# Out:
#         song_length      language        target          city            bd  \
# count  1.099686e+06  1.099686e+06  1.099686e+06  1.099686e+06  1.099686e+06
# mean   2.498562e+05  1.075631e+01  5.402760e-01  1.087418e+01  2.793846e+01
# std    4.378886e+04  1.610129e+01  4.983754e-01  5.861586e+00  2.292636e+01
# min    4.109000e+03 -1.000000e+00  0.000000e+00  1.000000e+00  0.000000e+00
# 25%    2.221440e+05  3.000000e+00  0.000000e+00  5.000000e+00  2.200000e+01
# 50%    2.486850e+05  3.000000e+00  1.000000e+00  1.300000e+01  2.600000e+01
# 75%    2.752260e+05  3.000000e+00  1.000000e+00  1.400000e+01  3.200000e+01
# max    4.793341e+06  5.900000e+01  1.000000e+00  2.200000e+01  1.030000e+03
#
#        registered_via  registration_init_time  expiration_date
# count    1.099686e+06            1.099686e+06     1.099686e+06
# mean     6.917714e+00            2.011849e+07     2.017207e+07
# std      2.592453e+00            3.215186e+04     4.117852e+03
# ...

# %%
df.isna().sum()
# Out:
# song_id                   0
# song_length               0
# genre_ids                 0
# artist_name               0
# composer                  0
# lyricist                  0
# language                  0
# name                      0
# isrc                      0
# msno                      0
# source_system_tab         0
# source_screen_name        0
# source_type               0
# target                    0
# city                      0
# bd                        0
# gender                    0
# registered_via            0
# registration_init_time    0
# expiration_date           0
# dtype: int64

# %%
df['registration_init_time'] = pd.to_datetime(df['registration_init_time'], format='%Y%m%d', errors='ignore')
df['registration_init_time_year'] = df['registration_init_time'].dt.year
df['registration_init_time_month'] = df['registration_init_time'].dt.month
df['registration_init_time_day'] = df['registration_init_time'].dt.day


df['expiration_date'] = pd.to_datetime(df['expiration_date'],  format='%Y%m%d', errors='ignore')
df['expiration_date_year'] = df['expiration_date'].dt.year
df['expiration_date_month'] = df['expiration_date'].dt.month
df['expiration_date_day'] = df['expiration_date'].dt.day
# Dates to categoty
df['registration_init_time'] = df['registration_init_time'].astype('category')
df['expiration_date'] = df['expiration_date'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1099686 entries, 0 to 3687887
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   song_id                 1099686 non-null  object
#  1   song_length             1099686 non-null  int64
#  2   genre_ids               1099686 non-null  object
#  3   artist_name             1099686 non-null  object
#  4   composer                1099686 non-null  object
#  5   lyricist                1099686 non-null  object
#  6   language                1099686 non-null  float64
#  7   name                    1099686 non-null  object
#  8   isrc                    1099686 non-null  object
#  9   msno                    1099686 non-null  object
#  10  source_system_tab       1099686 non-null  object
#  11  source_screen_name      1099686 non-null  object
#  12  source_type             1099686 non-null  object
# ...

# %%
df.drop(['registration_init_time','expiration_date'] , axis = 1 , inplace= True)

# %%
df.head(5)
# Out:
#                                         song_id  song_length genre_ids  \
# 0  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640       465
# 2  f8/yxXLT8/hENDkcudzHhytnOwyUKJ+/JCY7Y+L/Gsw=       237600       458
# 5  reXuGcEWDDCnL0K3Th//3DFG4S1ACSpJMzA+CFipo1g=       219324       458
# 6  AeFYUj/BA1epsa5mS3uQxbbS04PKiUr84gSVH430N24=       234631       458
# 8  F3L07h2BkUox3Uub/4K9LZ8Hg1JTlB2iEOEE9WpZ57A=       219350       458
#
#                         artist_name   composer         lyricist  language  \
# 0                  張信哲 (Jeff Chang)         董貞              何啟弘       3.0
# 2  八三夭 (The Last Day of Summer 831)     八三夭 阿璞           八三夭 阿璞       3.0
# 5                 周湯豪 (NICKTHEREAL)        周湯豪          周湯豪\崔惟楷       3.0
# 6                          Eric 周興哲  Eric Chou        Eric Chou       3.0
# 8                          Eric 周興哲  Eric Chou  Night Chun| Liv       3.0
#
#                         name          isrc  \
# 0                         焚情  TWB531410010
# ...

# %%
count_song_played_train = {k: v for k, v in df['song_id'].value_counts().items()}

def return_number_played(x):
    try:
        return count_song_played_train[x]
    except KeyError:
        return 0
df['number_of_time_played'] = df['song_id'].apply(lambda x: return_number_played(x))
df
# Out:
#          song_id  song_length  genre_ids  artist_name  composer  lyricist  \
# 0          10960        10991        129         4850     18506     14114
# 2          32219         9604        125         4475     15428     14275
# 5          41477         7082        125         4619     15795     14732
# 6           9525         9203        125         1129      4029      3564
# 8          12827         7085        125         1129      4029      9554
# ...          ...          ...        ...          ...       ...       ...
# 3687835    37990        12448        125           11      4029     13109
# 3687836    37990        12448        125           11      4029     13109
# 3687860    10959        17022        129         5180     19063     18777
# 3687881    19543         5159        186         3900     17650     16966
# 3687887     1299        15735        129         4883     18586     16306
#
#          language   name   isrc  msno  source_system_tab  source_screen_name  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Example data (replace this with your actual data)
data = df['number_of_time_played']

# Set the style for the plots
sns.set(style="whitegrid")

# Plot histogram
plt.figure(figsize=(10, 6))
sns.histplot(data, bins=30, kde=True, color='blue')
plt.title('Histogram of Number of Times Played')
plt.xlabel('Number of Times Played')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['target'],y=df['number_of_time_played'], color='lightcoral')
# Out:
# <Axes: xlabel='target', ylabel='number_of_time_played'>

# %%
# Plot boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['source_type'],y=df['number_of_time_played'])
# Out:
# <Axes: xlabel='source_type', ylabel='number_of_time_played'>

# %%
sns.histplot(x=df['bd'],bins=30, kde=True, color='blue')
# Out:
# <Axes: xlabel='bd', ylabel='Count'>

# %%
sns.boxplot(x=df['language'],y=df['number_of_time_played'])
# Out:
# <Axes: xlabel='language', ylabel='number_of_time_played'>

# %%
sns.boxplot(x=df['source_system_tab'], y=df['number_of_time_played'])
# Out:
# <Axes: xlabel='source_system_tab', ylabel='number_of_time_played'>

# %%
sns.boxplot(x=df['source_screen_name'], y=df['number_of_time_played'])
# Out:
# <Axes: xlabel='source_screen_name', ylabel='number_of_time_played'>

# %%
df.columns
# Out:
# Index(['song_id', 'song_length', 'genre_ids', 'artist_name', 'composer',
#        'lyricist', 'language', 'name', 'isrc', 'msno', 'source_system_tab',
#        'source_screen_name', 'source_type', 'target', 'city', 'bd', 'gender',
#        'registered_via', 'number_of_time_played'],
#       dtype='object')

# %%
sns.boxplot(x=df['city'], y=df['number_of_time_played'])
# Out:
# <Axes: xlabel='city', ylabel='number_of_time_played'>

# %%
sns.boxplot(x=df['registered_via'], y=df['number_of_time_played'])
# Out:
# <Axes: xlabel='registered_via', ylabel='number_of_time_played'>

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
label_encoder = LabelEncoder()

for i in df.columns :
    df[i] = label_encoder.fit_transform(df[i])

    
X = df.drop('target', axis = 1)
y = df.target
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
    model = LogisticRegression()
    model.fit(X_train, y_train)
    train_pred = model.predict(X_train)
    val_pred = model.predict(X_val)
    print(classification_report(y_train, train_pred))
    print(classification_report(y_val, val_pred))
    print("Accuracy :", accuracy_score(y_val, val_pred))
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       0.54      0.51      0.52    378926
#            1       0.60      0.64      0.62    445838
#
#     accuracy                           0.58    824764
#    macro avg       0.57      0.57      0.57    824764
# weighted avg       0.57      0.58      0.57    824764
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.51      0.52    126626
# ...
